# %%
import numpy as np
import pandas as pd
import warnings

# %%
warnings.filterwarnings('ignore')

# %% [markdown]
# # Get  the dataset

# %%
columns_names = ["user_id", "item_id", "rating", "timestamp"]

df = pd.read_csv("ml-100k/u.data", sep = '\t', names = columns_names)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [5], line 3
#       1 columns_names = ["user_id", "item_id", "rating", "timestamp"]
# ----> 3 df = pd.read_csv("ml-100k/u.data", sep = '\t', names = columns_names)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ml-100k/u.data'

# %%
df.head()

# %%
df.shape

# %%
df['user_id'].nunique()

# %%
df['item_id'].nunique()

# %%
movies_title = pd.read_csv("ml-100k/u.item", sep = "\|", header = None, encoding = "ISO-8859-1")

# %%
movies_title.shape

# %%
movies_title = movies_title[[0,1]]

# %%
movies_title.columns = ['item_id', 'title']

# %%
movies_title.head()

# %%
df = pd.merge(df, movies_title, on = "item_id")

# %%
df.tail()

# %% [markdown]
# # Exploratory Data Analysis

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set_style('white')

# %%
df.groupby('title').mean()['rating'].sort_values(ascending = False).head()

# %%
df.groupby('title').count()['rating'].sort_values(ascending = False)

# %%
ratings = pd.DataFrame(df.groupby('title').mean()['rating'])

# %%
ratings.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 ratings.head()
#
# NameError: name 'ratings' is not defined

# %%
ratings['num of ratings'] = pd.DataFrame(df.groupby('title').count()['rating'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 ratings['num of ratings'] = pd.DataFrame(df.groupby('title').count()['rating'])
#
# NameError: name 'df' is not defined

# %%
ratings.sort_values(by = 'rating', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 ratings.sort_values(by = 'rating', ascending = False)
#
# NameError: name 'ratings' is not defined

# %%
plt.figure(figsize = (10, 6))
plt.hist(ratings['num of ratings'], bins = 70)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 plt.figure(figsize = (10, 6))
#       2 plt.hist(ratings['num of ratings'], bins = 70)
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
plt.hist(ratings['rating'], bins = 70)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 plt.hist(ratings['rating'], bins = 70)
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.jointplot(x = 'rating', y = 'num of ratings', data = ratings, alpha = 0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 sns.jointplot(x = 'rating', y = 'num of ratings', data = ratings, alpha = 0.5)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Creating Movie Recommendation

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
moviemat = df.pivot_table(index = "user_id", columns = "title", values = "rating")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 moviemat = df.pivot_table(index = "user_id", columns = "title", values = "rating")
#
# NameError: name 'df' is not defined

# %%
moviemat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 moviemat
#
# NameError: name 'moviemat' is not defined

# %%
ratings.sort_values('num of ratings', ascending = False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [15], line 1
# ----> 1 ratings.sort_values('num of ratings', ascending = False).head()
#
# NameError: name 'ratings' is not defined

# %%
starwars_user_ratings = moviemat['Star Wars (1977)']
starwars_user_ratings.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 starwars_user_ratings = moviemat['Star Wars (1977)']
#       2 starwars_user_ratings.head()
#
# NameError: name 'moviemat' is not defined

# %%
similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 similar_to_starwars = moviemat.corrwith(starwars_user_ratings)
#
# NameError: name 'moviemat' is not defined

# %%
corr_starwars = pd.DataFrame(similar_to_starwars, columns = ['Correlation'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 corr_starwars = pd.DataFrame(similar_to_starwars, columns = ['Correlation'])
#
# NameError: name 'similar_to_starwars' is not defined

# %%
corr_starwars.dropna(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 corr_starwars.dropna(inplace = True)
#
# NameError: name 'corr_starwars' is not defined

# %%
corr_starwars.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 corr_starwars.head()
#
# NameError: name 'corr_starwars' is not defined

# %%
corr_starwars.sort_values('Correlation', ascending = False).head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 corr_starwars.sort_values('Correlation', ascending = False).head(10)
#
# NameError: name 'corr_starwars' is not defined

# %%
ratings
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 1
# ----> 1 ratings
#
# NameError: name 'ratings' is not defined

# %%
corr_starwars = corr_starwars.join(ratings['num of ratings'])
corr_starwars.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [23], line 1
# ----> 1 corr_starwars = corr_starwars.join(ratings['num of ratings'])
#       2 corr_starwars.head()
#
# NameError: name 'corr_starwars' is not defined

# %%
corr_starwars[corr_starwars['num of ratings'] > 100].sort_values('Correlation', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [24], line 1
# ----> 1 corr_starwars[corr_starwars['num of ratings'] > 100].sort_values('Correlation', ascending = False)
#
# NameError: name 'corr_starwars' is not defined

# %% [markdown]
# # Pridiction Function

# %%
def predict_movies(movie_name):
    movie_user_ratings = moviemat[movie_name]
    similar_to_movie = moviemat.corrwith(movie_user_ratings)
    
    corr_movie = pd.DataFrame(similar_to_movie, columns = ['Correlation'])
    corr_movie.dropna(inplace = True)
    
    corr_movie = corr_movie.join(ratings['num of ratings'])
    predictions = corr_movie[corr_movie['num of ratings'] > 100].sort_values('Correlation', ascending = False)
    
    return predictions

# %%
predictions = predict_movies("Giant (1956)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 predictions = predict_movies("Giant (1956)")
#
# Cell In [25], line 2, in predict_movies(movie_name)
#       1 def predict_movies(movie_name):
# ----> 2     movie_user_ratings = moviemat[movie_name]
#       3     similar_to_movie = moviemat.corrwith(movie_user_ratings)
#       5     corr_movie = pd.DataFrame(similar_to_movie, columns = ['Correlation'])
#
# NameError: name 'moviemat' is not defined

# %%
predictions.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [27], line 1
# ----> 1 predictions.head()
#
# NameError: name 'predictions' is not defined
